# %%
print(f"idm 测试 不同TestSize的程序：一次性测试0.95,0.9.0.7,0.5")
# !python model9idmRTlost.py --num_types 4 --batch_size  390 --test_size 0.95 --epochs 2000 --lr 0.0005 --unit 256 --layNum 128 --dt 0.1 --nC 0 --model 0 --fixdata 0 --trainvalmode 0 --goffset 1 > idmTS95.log
# !python model9idmRTlost.py --num_types 4 --batch_size  780 --test_size 0.90 --epochs 2000 --lr 0.0005 --unit 256 --layNum 128 --dt 0.1 --nC 0 --model 0 --fixdata 0 --trainvalmode 0 --goffset 1 > idmTS90.log 
# !python model9idmRTlost.py --num_types 4 --batch_size 1100 --test_size 0.70 --epochs 2000 --lr 0.0005 --unit 256 --layNum 128 --dt 0.1 --nC 0 --model 0 --fixdata 0 --trainvalmode 0 --goffset 1 > idmTS70.log 
# !python model9idmRTlost.py --num_types 4 --batch_size 1300 --test_size 0.50 --epochs 2000 --lr 0.0005 --unit 256 --layNum 128 --dt 0.1 --nC 0 --model 0 --fixdata 0 --trainvalmode 0 --goffset 1 > idmTS50.log

# %%
print(f"idm 测试 不同TestSize的程序：一次性测试0.7")
# !python model9idmRTlost.py --num_types 4 --batch_size 1100 --test_size 0.70 --epochs 2000 --lr 0.0005 --unit 256 --layNum 128 --dt 0.1 --nC 0 --model 0 --fixdata 0 --trainvalmode 0 --goffset 1 > idmTS70.log

# %%
print(f"w99reg_model1_测试基于v0主车速度分层测试,model1")
# !python model9w99RTlost.py --num_types 4 --batch_size  1300 --test_size 0.5 --epochs 1000 --lr 0.0005 --unit 256 --layNum 128 --dt 0.1 --nC 0 --model 1 --fixdata 0 --trainvalmode 2  --v0split 0.01 --goffset 1 > w9M1_TM4V05TS50.log

# %%
print(f"w99cf_model0测试基于v0主车速度分层测试,model0")
# !python model9w99RTlost.py --num_types 4 --batch_size  1300 --test_size 0.5 --epochs 1000 --lr 0.0005 --unit 256 --layNum 128 --dt 0.1 --nC 0 --model 0 --fixdata 0 --trainvalmode 2  --v0split 0.01 --goffset 1 > w99M0_TV2_V0S001.log

# %%
print(f"idm测试基于v0主车速度分层测试,model0")
# !python model9idmRTlost.py --num_types 4 --batch_size  1900 --test_size 0.5 --epochs 1000 --lr 0.0005 --unit 256 --layNum 128 --dt 0.1 --nC 0 --model 0 --fixdata 0 --trainvalmode 2  --v0split 0.01 --goffset 1 > idmM0_TV2_V0S001.log

# %%
print(f"fvdm测试基于排队车辆分层测试,model0")
# !python model9fvdmRTlost.py --num_types 4 --batch_size  1900 --test_size 0.5 --epochs 1000 --lr 0.0005 --unit 256 --layNum 128 --dt 0.1 --nC 0 --model 0 --fixdata 0 --trainvalmode 3  --quesplit 1 --goffset 1 > fvdmM0_TV3_QueSP1.log
# Out:
# fvdm测试基于排队车辆分层测试,model0
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
